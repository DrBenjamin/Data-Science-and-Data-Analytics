# %% [markdown]
# # Spotify API example

# %%
#Installing spotipy library so we can use pre defined functions that are going to be helpful for the purpose of this EDA project.
# !python -m pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /Users/ben/conda/envs/r-reticulate/lib/python3.13/site-packages (2.25.1)
# Requirement already satisfied: redis>=3.5.3 in /Users/ben/conda/envs/r-reticulate/lib/python3.13/site-packages (from spotipy) (7.1.0)
# Requirement already satisfied: requests>=2.25.0 in /Users/ben/conda/envs/r-reticulate/lib/python3.13/site-packages (from spotipy) (2.32.5)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/ben/conda/envs/r-reticulate/lib/python3.13/site-packages (from spotipy) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ben/conda/envs/r-reticulate/lib/python3.13/site-packages (from requests>=2.25.0->spotipy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ben/conda/envs/r-reticulate/lib/python3.13/site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ben/conda/envs/r-reticulate/lib/python3.13/site-packages (from requests>=2.25.0->spotipy) (2025.8.3)

# %% [markdown]
# ## Connection to Spotify API using Spotipy
#
# This example...

# %%
# Import necessary libraries
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# Set up spotipy client
client_id = 'abe5aaad8c654f8ea062c143c03661e7'
client_secret = '4d966919b0fb4ad09f5d2a5ced21d9e0'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ## Playlist Analysis

# %%
# Function to get the tracks from a playlist
def get_playlist_tracks(playlist_id):
   # Get the tracks from the specified playlist
    playlist_tracks = sp.playlist_tracks(playlist_id)

    # Extract track details
    track_details = []
    for item in playlist_tracks['items']:
        track = item['track']
        details = {}
        details['id'] = track['id']
        details['name'] = track['name']
        details['artist'] = track['artists'][0]['name']
        details['duration_ms'] = track['duration_ms']
        details['popularity'] = track['popularity']

        # Get audio features for each track
        audio_features = sp.audio_features(track['id'])[0]
        details['danceability'] = audio_features['danceability']
        details['energy'] = audio_features['energy']
        details['key'] = audio_features['key']
        details['loudness'] = audio_features['loudness']
        details['mode'] = audio_features['mode']
        details['speechiness'] = audio_features['speechiness']
        details['acousticness'] = audio_features['acousticness']
        details['instrumentalness'] = audio_features['instrumentalness']
        details['liveness'] = audio_features['liveness']
        details['valence'] = audio_features['valence']
        details['tempo'] = audio_features['tempo']

        track_details.append(details)

    # Convert to dataframe
    df = pd.DataFrame(track_details)

    return df

# Get the tracks from the global top 50 playlist
global_top_50 = get_playlist_tracks('37i9dQZEVXbMDoHDwVN2tF')
global_top_50.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/conda/envs/r-reticulate/lib/python3.13/site-packages/spotipy/oauth2.py:232, in SpotifyClientCredentials._request_access_token(self)
#     224 response = self._session.post(
#     225     self.OAUTH_TOKEN_URL,
#     226     data=payload,
#    (...)    230     timeout=self.requests_timeout,
#     231 )
# --> 232 response.raise_for_status()
#     233 token_info = response.json()
#
# File ~/conda/envs/r-reticulate/lib/python3.13/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://accounts.spotify.com/api/token
#
# During handling of the above exception, another exception occurred:
#
# SpotifyOauthError                         Traceback (most recent call last)
# Cell In[3], line 39
#      36     return df
#      38 # Get the tracks from the global top 50 playlist
# ---> 39 global_top_50 = get_playlist_tracks('37i9dQZEVXbMDoHDwVN2tF')
#      40 global_top_50.head()
#
# Cell In[3], line 4, in get_playlist_tracks(playlist_id)
#       2 def get_playlist_tracks(playlist_id):
#       3    # Get the tracks from the specified playlist
# ----> 4     playlist_tracks = sp.playlist_tracks(playlist_id)
#       6     # Extract track details
#       7     track_details = []
#
# File ~/conda/envs/r-reticulate/lib/python3.13/site-packages/spotipy/client.py:700, in Spotify.playlist_tracks(self, playlist_id, fields, limit, offset, market, additional_types)
#     684 """ Get full details of the tracks of a playlist.
#     685
#     686     Parameters:
#    (...)    693                              valid types are: track and episode
#     694 """
#     695 warnings.warn(
#     696     "You should use `playlist_items(playlist_id, ...,"
#     697     "additional_types=('track',))` instead",
#     698     DeprecationWarning,
#     699 )
# --> 700 return self.playlist_items(playlist_id, fields, limit, offset,
#     701                            market, additional_types)
#
# File ~/conda/envs/r-reticulate/lib/python3.13/site-packages/spotipy/client.py:724, in Spotify.playlist_items(self, playlist_id, fields, limit, offset, market, additional_types)
#     712 """ Get full details of the tracks and episodes of a playlist.
#     713
#     714     Parameters:
#    (...)    721                              valid types are: track and episode
#     722 """
#     723 plid = self._get_id("playlist", playlist_id)
# --> 724 return self._get(
#     725     f"playlists/{plid}/tracks",
#     726     limit=limit,
#     727     offset=offset,
#     728     fields=fields,
#     729     market=market,
#     730     additional_types=",".join(additional_types)
#     731 )
#
# File ~/conda/envs/r-reticulate/lib/python3.13/site-packages/spotipy/client.py:324, in Spotify._get(self, url, args, payload, **kwargs)
#     321 if args:
#     322     kwargs.update(args)
# --> 324 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/conda/envs/r-reticulate/lib/python3.13/site-packages/spotipy/client.py:250, in Spotify._internal_call(self, method, url, payload, params)
#     248 if not url.startswith("http"):
#     249     url = self.prefix + url
# --> 250 headers = self._auth_headers()
#     252 if "content_type" in args["params"]:
#     253     headers["Content-Type"] = args["params"]["content_type"]
#
# File ~/conda/envs/r-reticulate/lib/python3.13/site-packages/spotipy/client.py:241, in Spotify._auth_headers(self)
#     239     return {}
#     240 try:
# --> 241     token = self.auth_manager.get_access_token(as_dict=False)
#     242 except TypeError:
#     243     token = self.auth_manager.get_access_token()
#
# File ~/conda/envs/r-reticulate/lib/python3.13/site-packages/spotipy/oauth2.py:207, in SpotifyClientCredentials.get_access_token(self, as_dict, check_cache)
#     204     if token_info and not self.is_token_expired(token_info):
#     205         return token_info if as_dict else token_info["access_token"]
# --> 207 token_info = self._request_access_token()
#     208 token_info = self._add_custom_values_to_token_info(token_info)
#     209 self.cache_handler.save_token_to_cache(token_info)
#
# File ~/conda/envs/r-reticulate/lib/python3.13/site-packages/spotipy/oauth2.py:236, in SpotifyClientCredentials._request_access_token(self)
#     234     return token_info
#     235 except requests.exceptions.HTTPError as http_error:
# --> 236     self._handle_oauth_error(http_error)
#
# File ~/conda/envs/r-reticulate/lib/python3.13/site-packages/spotipy/oauth2.py:117, in SpotifyAuthBase._handle_oauth_error(self, http_error)
#     114     error = response.text or None
#     115     error_description = None
# --> 117 raise SpotifyOauthError(
#     118     f'error: {error}, error_description: {error_description}',
#     119     error=error,
#     120     error_description=error_description
#     121 )
#
# SpotifyOauthError: error: invalid_client, error_description: Invalid client
